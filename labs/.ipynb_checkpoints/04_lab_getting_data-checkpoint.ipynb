# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
##### INDEED #####

# a job posting website (as well as resume hosting)
# scrape some (or A LOT) of job postings from indeed for the job "data scientist"
# Plan of Action:
# 1. Figure out the url for getting the summaries (by doing it yourself!)
# 2. Scrape the summary
# 3. Figure out how to change the page by changing the URL (hint, click the next page button and see how the url changes)
# 4. BONUS: count the most used words in the sumaries

# %%
# 1. Figure out the url for getting the summaries (by doing it yourself!)
site= requests.get('http://www.indeed.com/jobs?q=data+scientist&l=')
site.status_code
# Out:
# 200

# %%
# 2. Scrape the summary
dsjobs= BeautifulSoup(site.text, "html.parser") # create a beautifulsoup object
dsjobs.prettify() # will print the html nicely
# Out:
# u'<!DOCTYPE html>\n<html>\n <head>\n  <meta content="text/html;charset=utf-8" http-equiv="content-type">\n   <!-- pll -->\n   <script src="/s/31f239c/en_US.js" type="text/javascript">\n   </script>\n   <link href="/s/2a09b15/jobsearch_all.css" rel="stylesheet" type="text/css">\n    <link href="http://rss.indeed.com/rss?q=data+scientist" rel="alternate" title="Data Scientist Jobs, Employment" type="application/rss+xml">\n     <link href="/m/jobs?q=data+scientist" media="handheld" rel="alternate">\n      <script type="text/javascript">\n       window[\'closureReadyCallbacks\'] = [];\n\n    function call_when_jsall_loaded(cb) {\n        if (window[\'closureReady\']) {\n            cb();\n        } else {\n            window[\'closureReadyCallbacks\'].push(cb);\n        }\n    }\n      </script>\n      <script src="/s/9ffce4f/jobsearch-all-compiled.js" type="text/javascript">\n      </script>\n      <script type="text/javascript">\n       var pingUrlsForGA = [];\n\nvar searchUID = \'1ahd4bk11ag1395u\';\nvar tk = \'1ahd4bk11ag1395u\';\n\nvar loggedIn = false;\nvar myindeed = true;\nvar userEmail = \'\';\nvar tellFriendEmail = \'\';\nvar globalLoginURL = \'http:\\/\\/www.indeed.com\\/account\\/login?dest=%2Fq-data-scientist-jobs.html\';\nvar globalRegisterURL = \'http:\\/\\/www.indeed.com\\/account\\/register?dest=%2Fq-data-scientist-jobs.html\';\nvar searchKey = \'bebb41335ed80f2a\';\nvar searchState = \'q=data+scientist&amp;\';\nvar searchQS = \'q=data+scientist\';\nvar eventType = \'jobsearch\';\nvar locale = \'en_US\';\nfunction clk(id) { var a = document.getElementById(id); var hr = a.href; var si = a.href.indexOf(\'&jsa=\'); if (si > 0) return; var jsh = hr + \'&tk=1ahd4bk11ag1395u&jsa=5345\'; a.href = jsh; }\nfunction sjomd(id) { var a = document.getElementById(id); var hr = a.href; var ocs = hr.indexOf(\'&oc=1\'); if (ocs < 0) return; var oce = ocs + 5; a.href = hr.substring(0, ocs) + hr.substring(oce); }\nfunction sjoc(id, sal) { var a = document.getElementById(id); a.href = a.href + \'&oc=1&sal=\'+sal; }\nfunction ptk(st,p) {document.cookie = \'PTK="tk=1ahd4bk11ag1395u&type=jobsearch&subtype=\'+st+(p?\'&\'+p:\'\')+\'"; path=/\';}\nfunction rbptk(st, c, p) { ptk(st, \'cat=\'+c+(p?\'&p=\'+p:\'\'));}\n      </script>\n      <script type="text/javascript">\n       function loadJSAsync( ) {\nfor ( var i = 0; i < arguments.length; i++ ) {\nvar url = arguments[i];\n(function() {\nvar s = document.createElement("script"), el = document.getElementsByTagName("script")[0];\ns.async = true;\ns.src = url;\nel.parentNode.insertBefore(s, el);\n})();\n}\n}\n      </script>\n      <meta content="21,947  Data Scientist Jobs available on Indeed.com.  one search.  all jobs." name="description">\n       <meta content="Data Scientist Jobs, Employment,  careers,  employment,  job listings,  job search,  search engine, work in " name="keywords">\n        <link href="/q-Data-Scientist-jobs.html" rel="canonical">\n         <style type="text/css">\n          #recPromoDisplay { margin-bottom: 3em;margin-left: 0.5em; }\n#recPromoDisplayPageLast { font-size: 16px; margin: 1.5em 0; }\n         </style>\n         <script type="text/javascript">\n          var indeedCsrfToken = \'Qwh0IGsh3p7z6ifkMRKNdzH7cZ2HfevJ\';\nvar hashedCsrfToken = \'e20f51a2748ce8fe805c785ee07003b7\';\n         </script>\n         <style type="text/css">\n          .jasxcustomfonttst-useCustomHostedFontFullPage *{font-family:"Open Sans", sans-serif !important}\n         </style>\n         <style type="text/css">\n          #resultsCol { padding-top: 0; }\n.searchCount { margin-top: 6px; }\n.showing { padding-top: 9px; padding-bottom: 9px; }\n\n.brdr { height: 1px; overflow: hidden; background-color: #ccc; }\n\n#bjobalerts { margin-top: 0; }\n\n/* Tall window sizes */\n@media only screen and (min-height:780px){\n.showing { padding-bottom: 0; }\n}\n\n/* Wide window sizes */\n@media only screen and (min-width:1125px){\n.brdr  { margin-left: 12px; margin-right: 12px; }\n}\n\na,a:link,. ...

# %%
alljobs = dsjobs.findAll('div', {"class": "row"})

# %%
ds_job_titles=[]
for x in alljobs:
    titles = x.text
    ds_job_titles.append(titles)
ds_job_titles
#this is getting the first job but then Idk where the rest of the text is coming from
# Out:
# [u'\nData Scientist\n\n\n\n    EightSquared Consulting, LLC -\n\n - Mahwah, NJ\n\n\nData Scientist, BI Analytics role is an individual contributor, leading the design and delivery of analytic....\n\n\n Easily apply\n\n\nSponsored - 30+ days ago   -  emailwindow[\'sj_result_8a6ebaec2de16a3e\'] = {"showSource": false, "source": "Indeed", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "30+ days ago","jobKey": "8a6ebaec2de16a3e", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": false, "resultNumber": 10, "jobStateChangedToSaved": false, "searchState": "q=data scientist&amp;", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": false, "currentPage" : "serp", "sponsored" : true,"showSponsor" : true,"reportJobButtonEnabled": false};\n\n\n\n',
#  u'\nData Scientist/Data Engineer\n\n\n\n\n    Novetta\n\n - \n3.05 reviews\n - National Harbor, MD\n\n\nNovetta is seeking a Data Engineer or Data Scientist interested in creating scalable ETL solutions and solving analytical challenges!...\n\n\nSponsored - 30+ days ago   -  emailwindow[\'sj_result_9373d8d38777b7f1\'] = {"showSource": false, "source": "Novetta", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "30+ days ago","jobKey": "9373d8d38777b7f1", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": false, "resultNumber": 11, "jobStateChangedToSaved": false, "searchState": "q=data scientist&amp;", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": false, "currentPage" : "serp", "sponsored" : true,"showSponsor" : true,"reportJobButtonEnabled": false};\n\n\n\n',
#  u'\nData Scientist\n\n\n\n\n    The Washington Post\n\n - \n3.841 reviews\n - Washington, DC\n\n\nData scientist will utilize the data from the platform and design and build systems that apply machine learning, statistical modeling, NLP (Natural Language...\n\n\nSponsored - 30+ days ago   -  emailwindow[\'sj_result_741ea34c19ac4491\'] = {"showSource": false, "source": "The Washington Post", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "30+ days ago","jobKey": "741ea34c19ac4491", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": false, "resultNumber": 12, "jobStateChangedToSaved": false, "searchState": "q=data scientist&amp;", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": false, "currentPage" : "serp", "sponsored" : true,"showSponsor" : true,"reportJobButtonEnabled": false};\n\n\n\n',
#  u'\n\nData Scientist (San Francisco)\n\n\n\n\n    Etsy\n\n\n - \n4.813 reviews\n - San Francisco, CA\n\xa0+1 location\n\n\n\n\nThis is a job for someone with a background in Information Retrieval, Machine Learning, Deep Learning, Computer Vision or Statistics....\n\n\n8 days ago  - save job  -  email - more...window[\'result_e54145f246541eeb\'] = {"showSource": false, "source": "Etsy", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "8 days ago","jobKey": "e54145f246541eeb", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 0, "jobStateChangedToSaved": false, "searchState": "q=data scientist&amp;", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false};\n\nView all Etsy jobs in San Francisco, CA - San Francisco jobsSalary Search: Data Scientist salaries in San Francisco, CALearn more about working at EtsyRelated forums: SAN Francisco, California - Etsy\n\n\n\n\n\n\n\n',
#  u'\n\nData Scientist\n\n\n\n    21, Inc\n\n\n - San Francisco, CA\n\n\n\n\n\nYou know how to code better than most statisticians and do stats better than most computer scientists :. Develop and implement data collection systems and data...\n\n\n11 days ago  - save job  -  email - more...window[\'result_f508040177fb10f9\'] = {"showSource": false, "source": "21, Inc", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "11 days ago","jobKey": "f508040177fb10f9", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 1, "jobStateChangedToSaved": false, "searchState": "q=data scientist&amp;", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false};\n\nView all 21, Inc jobs in San Francisco, CA - San Francisco jobsSalary Search: Data Scientist salaries in San Francisco, CALearn more about working at 21, IncRelated forums: SAN Francisco, California - 21, Inc\n\n\n\n\n\n\n\n',
#  u'\n\nData Scientist\n\n\n\n\n    TaskRabbit\n\n\n - \n4.47 reviews\n - San Francisco, CA\n\n\n\n\n\nAdvanced degree in computer science/engineering, with a background in machine learning, predictive models, classification, data mining....\n\n\n Easily apply\n\n\n6 days ago  - save job  -  email - more...window[\'result_1f19962d1892a1f0\'] = {"showSource": false, "source": "TaskRabbit", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "6 days ago","jobKey": "1f19962d1892a1f0", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 2, "jobStateChangedToSaved": false, "searchState": "q=data scientist&amp;", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false};\n\nView all TaskRabbit jobs in San Francisco, CA - San Francisco jobsSalary Search: Data Scientist salaries in San Francisco, CALearn more about working at TaskrabbitRelated forums: TaskRabbit - SAN Francisco, California\n\n\n\n\n\n\n\n',
#  u'\n\nMachine Learning Engineer\n\n\n\n\n    Index\n\n\n - \n3.929 reviews\n - San Francisco, CA\n\n\n\n\n\nHave developed machine learning infrastructure. Seeking deep understanding. Have experience with Hadoop or other Big Data platforms....\n\n\n Easily apply\n\n\n5 days ago  - save job  -  email - more...window[\'result_36a0907767f15ea6\'] = {"showSource": false, "source": "Index", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "5 days ago","jobKey": "36a0907767f15ea6", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 3, "jobStateChangedToSaved": false, "searchState": "q=data scientist&amp;", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false};\n\nView all Index jobs in San Francisco, CA - San Francisco jobsSalary Search: Machine Learning Engineer salaries in San Francisco, CALearn more about working at IndexRelated forums: Index - SAN Francisco, California\n\n\n\n\n\n\n\n',
#  u'\n\nData Scientist\n\n\n\n\n    Dropbox\n\n\n - \n4.03 reviews\n - San Francisco, CA\n\n\n\n\n\nDevelop and communicate a deep understanding of lifecycle marketing needs, perform analytical deep-dives to identify problems, opportunities and specific...\n\n\n19 days ago  - save job  -  email - more...window[\'result_a66b8f5d85f56b41\'] = {"showSource": false, "source": "Dropbox", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "19 days ago","jobKey": "a66b8f5d85f56b41", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 4, "jobStateChangedToSaved": false, "searchState": "q=data scientist&amp;", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false};\n\nView all Dropbox jobs in San Francisco, CA - San Francisco jobsSalary Search: Data Scientist salaries in San Francisco, CALearn more about working at DropboxRelated forums: Dropbox - SAN Francisco, California\n\n\n\n\n\n\n\n',
#  u'\n\nData Scientist\n\n\n\n\n    Apple\n\n\n - \n4.32,221 reviews\n - San Francisco, CA 94114 (Castro-Upper Market area)\n\xa0+1 location\n\n\n\n\nWe are looking for scientists who are passionate about creating data driven systems and have experience in statistical programming, machine learning, and use of...\n\n\n30+ days ago  - save job  -  email - more...window[\'result_1c8a8b97175b214b\'] = {"showSource": false, "source": "Apple", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "30+ days ago","jobKey": "1c8a8b97175b214b", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 5, "jobStateChangedToSaved": false, "searchState": "q=data scientist&amp;", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false};\n\nView all Apple jobs in San Francisco, CA - San Francisco jobsSalary Search: Data Scientist salaries in San Francisco, CALearn more about working at AppleRelated forums: SAN Francisco, California - Apple\n\n\n\n\n\n\n\n',
#  u'\n\nData Scientist - Statistician\n\n\n\n\n    Premise\n\n\n - \n4.84 reviews\n - San Francisco, CA\n\n\n\n\n\nPython, R, SQL. Premise is a mobile data and analytics platform bringing visibility to the world\u2019s hardest-to-see places....\n\n\n Easily apply\n\n\n17 days ago  - save job  -  email - more...window[\'result_75d0da802794dfbc\'] = {"showSource": false, "source": "Premise", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "17 days ago","jobKey": "75d0da802794dfbc", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 6, "jobStateChangedToSaved": false, "searchState": "q=data scientist&amp;", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false};\n\nView all Premise jobs in San Francisco, CA - San Francisco jobsSalary Search: Data Scientist salaries in San Francisco, CALearn more about working at PremiseRelated forums: Premise - SAN Francisco, California\n\n\n\n\n\n\n\n',
#  u'\n\nData Scientist\n\n\n\n\n    Instacart\n\n\n - \n3.153 reviews\n - San Francisco, CA\n\n\n\n\n\nWe are creating the best way for people to shop for groceries by applying data, algorithms and machine learning to problems in logistics, retail,...\n\n\n Easily apply\n\n\n1 day ago  - save job  -  email - more...window[\'result_054e885ddf058e8c\'] = {"showSource": false, "source": "Instacart", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "1 day ago","jobKey": "054e885ddf058e8c", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 7, "jobStateChangedToSaved": false, "searchState": "q=data scientist&amp;", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false};\n\nView all Instacart jobs in San Francisco, CA - San Francisco jobsSalary Search: Data Scientist salaries in San Francisco, CALearn more about working at InstacartRelated forums: Instacart - SAN Francisco, California\n\n\n\n\n\n\n\n',
#  u'\n\nData Scientist - Yammer\n\n\n\n\n    Microsoft\n\n\n - \n4.22,200 reviews\n - San Francisco, CA\n\n\n\n\n\nOur data scientists are exceptional thinkers, all in their own unique way. The Yammer Analytics team influences decision making across Microsoft by discovering...\n\n\n24 days ago  - save job  -  email - more...window[\'result_2865e3e9cd95624e\'] = {"showSource": false, "source": "Microsoft", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "24 days ago","jobKey": "2865e3e9cd95624e", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 8, "jobStateChangedToSaved": false, "searchState": "q=data scientist&amp;", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false};\n\nView all Microsoft jobs in San Francisco, CA - San Francisco jobsSalary Search: Data Scientist salaries in San Francisco, CALearn more about working at MicrosoftRelated forums: SAN Francisco, California - Microsoft\n\n\n\n\n\n\n\n',
#  u'\n\nData Scientist, Growth\n\n\n\n\n    Square\n\n\n - \n3.712 reviews\n - San Francisco, CA 94103 (South Of Market area)\n\n\n\n\n\nUse your experience in analytics tools and scientific rigor to produce actionable insights. As a Data Scientist at Square you will lead projects that derive...\n\n\n14 days ago  - save job  -  email - more...window[\'result_7141c5f210c254fc\'] = {"showSource": false, "source": "Square", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "14 days ago","jobKey": "7141c5f210c254fc", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": true, "resultNumber": 9, "jobStateChangedToSaved": false, "searchState": "q=data scientist&amp;", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": true, "currentPage" : "serp", "sponsored" : false,"reportJobButtonEnabled": false};\n\nView all Square jobs in San Francisco, CA - San Francisco jobsSalary Search: Data Scientist salaries in San Francisco, CALearn more about working at SquareRelated forums: Square - SAN Francisco, California\n\n\n\n\n\n\n\n',
#  u'\nData Scientist\n\n\n\n\n    Indeed\n\n - \n4.5122 reviews\n - San Francisco, CA\n\n\nHow A Data Scientist Works. Work experience analyzing lots of data, for example in biotechnology, astrophysics or particle physics experiments, quantitative...\n\n\n Easily apply\n\n\nSponsored - 30+ days ago   -  emailwindow[\'sj_result_b892a5a9e9607cd8\'] = {"showSource": false, "source": "Indeed", "loggedIn": false, "showMyJobsLinks": true,"undoAction": "unsave","relativeJobAge": "30+ days ago","jobKey": "b892a5a9e9607cd8", "myIndeedAvailable": true, "tellAFriendEnabled": true, "showMoreActionsLink": false, "resultNumber": 13, "jobStateChangedToSaved": false, "searchState": "q=data scientist&amp;", "basicPermaLink": "http://www.indeed.com", "saveJobFailed": false, "removeJobFailed": false, "requestPending": false, "notesEnabled": false, "currentPage" : "serp", "sponsored" : true,"showSponsor" : true,"reportJobButtonEnabled": false};\n\n\n\n']

# %%
all_descrips = dsjobs.findAll('span', {"class": "summary"})

# %%
ds_job_descrips = []
for x in all_descrips:
    descrip = x.text
    ds_job_descrips.append(descrip)
ds_job_descrips
# Out:
# [u'Data Scientist, BI Analytics role is an individual contributor, leading the design and delivery of analytic....',
#  u'Novetta is seeking a Data Engineer or Data Scientist interested in creating scalable ETL solutions and solving analytical challenges!...',
#  u'Data scientist will utilize the data from the platform and design and build systems that apply machine learning, statistical modeling, NLP (Natural Language...',
#  u'\nThis is a job for someone with a background in Information Retrieval, Machine Learning, Deep Learning, Computer Vision or Statistics....',
#  u'\nYou know how to code better than most statisticians and do stats better than most computer scientists :. Develop and implement data collection systems and data...',
#  u'\nAdvanced degree in computer science/engineering, with a background in machine learning, predictive models, classification, data mining....',
#  u'\nHave developed machine learning infrastructure. Seeking deep understanding. Have experience with Hadoop or other Big Data platforms....',
#  u'\nDevelop and communicate a deep understanding of lifecycle marketing needs, perform analytical deep-dives to identify problems, opportunities and specific...',
#  u'\nWe are looking for scientists who are passionate about creating data driven systems and have experience in statistical programming, machine learning, and use of...',
#  u'\nPython, R, SQL. Premise is a mobile data and analytics platform bringing visibility to the world\u2019s hardest-to-see places....',
#  u'\nWe are creating the best way for people to shop for groceries by applying data, algorithms and machine learning to problems in logistics, retail,...',
#  u'\nOur data scientists are exceptional thinkers, all in their own unique way. The Yammer Analytics team influences decision making across Microsoft by discovering...',
#  u'\nUse your experience in analytics tools and scientific rigor to produce actionable insights. As a Data Scientist at Square you will lead projects that derive...',
#  u'How A Data Scientist Works. Work experience analyzing lots of data, for example in biotechnology, astrophysics or particle physics experiments, quantitative...']

# %%
#combine the two lists you get above into a dataframe
import pandas as pd 
Opportunity = Dataframe(ds_job_titles=index)

# %%
# the pattern we recognized from the website
#re_tag = re.compile("ref_\d+_l")

# %%
#### UFO ######

# SCRAPE ALL SIGHTINGS in 2015
# Plan of action
# 1. Figure out the pattern to get a certain year and month from nuforc
# 2. Scrape each sightings
# 3. Make a dataframe out of it
# 4. make a day column
# 5. graph each day in 2015 and see which day had the most! (Is it July 4th?)

# %%
##### TWITTER ######

# Create a dataframe where each row is a tweet that uses any tag you choose!
# include a column for date, text, user handle, user name, and user image
# You can use the normal query method and not stream for this!
